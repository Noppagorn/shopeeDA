# %%
import numpy as np
import pandas as pd

# %%
pdObj = pd.read_json('contacts.json')
print(pdObj)
# Out:
#         Contacts                         Email      Id  \
# 0              1                gkzAbIy@qq.com       0
# 1              4                                     1
# 2              0                                     2
# 3              0            mdllpYmE@gmail.com       3
# 4              2                                     4
# 5              0                                     5
# 6              4      hESiBgYTxMnj@hotmail.com       6
# 7              1      hqyunTiaXfIjhO@yahoo.com       7
# 8              2       XGUjcSiDpFKWEUCs@qq.com       8
# 9              0        osIIQgAiZX@hotmail.com       9
# 10             3                                    10
# 11             0                QRamvop@qq.com      11
# 12             2               QexYMLXc@qq.com      12
# 13             1   YsKhkKGJoQSNniHcr@yahoo.com      13
# 14             4                                    14
# 15             4                                    15
# ...

# %%
# Out:
#                   0                          1           2       \
# Contacts               1                          4           0
# Email     gkzAbIy@qq.com
# Id                     0                          1           2
# OrderId                   vDDJJcxfLtSfkooPhbYnJdxov
# Phone                                  329442681752  9125983679
#
#                              3          4          5       \
# Contacts                          0          2          0
# Email            mdllpYmE@gmail.com
# Id                                3          4          5
# OrderId   bHquEnCbbsGLqllwryxPsNOxa
# Phone                                300364407  840113148
#
#                             6                          7       \
# Contacts                         4                          1
# Email     hESiBgYTxMnj@hotmail.com   hqyunTiaXfIjhO@yahoo.com
# Id                               6                          7
# OrderId                             vxjYZtMUvNhtEBDruzQfjpsmX
# ...

# %%
pdObj.to_csv("contacts.csv",index=False)
